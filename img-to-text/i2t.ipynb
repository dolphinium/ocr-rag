# %%
import easyocr

# %%
# Create an OCR reader object
reader = easyocr.Reader(['tr'])

# Read text from an image
result = reader.readtext('../images_jpg/1.jpg')

# Print the extracted text
for detection in result:
    print(detection[1])
# Out:
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% CompleteBOMBA ÖDEV
# "Alo; anne eve gelmek üzereyim de gelirken pas-
# kurabiye alsam
# olur mu? Tamam, yemekten
# J)
# sonra, tamam;
# yemem; tamam
# annee.
# deyip
# telefonu kapattı Hayri.
# Pastaneye yaklaştığı; burnuna gelen taze; çikolatalı
# bomba kurabiye kokusundan belli oluyordu; Annesinin
# sağlıklı kek ve kurabiyeleri de güzeldi ama Cemil amca-
# nın bomba kurabivesi gibi değildi; Hemen pastanenin
# cam kapısını itip içeri girdi. Elindeki telefonu cebine
# koyarken gözlerini kapayıp mis gibi taze pişmiş kura-
# biye kokusunu içine
# Cemil amca elinde tepsiyle
# boncuklu mutfak kapısından tezgah tarafina geçti.
# Ul
# Ooo, Hayri Efendi
# geldin; aldın tabii bombanın
# kokusunu:" diyen
# Cemil
# amca, deniz topunu andıran
# koca göbeğini hoplatarak kahkaha attı. Hayri gözlerini
# açıp:
# ...

# %%
result
# Out:
# [([[np.int32(1070), np.int32(256)],
#    [np.int32(2043), np.int32(256)],
#    [np.int32(2043), np.int32(412)],
#    [np.int32(1070), np.int32(412)]],
#   'BOMBA ÖDEV',
#   np.float64(0.82195949361056)),
#  ([[np.int32(494), np.int32(409)],
#    [np.int32(2646), np.int32(409)],
#    [np.int32(2646), np.int32(573)],
#    [np.int32(494), np.int32(573)]],
#   '"Alo; anne eve gelmek üzereyim de gelirken pas-',
#   np.float64(0.6888478175164339)),
#  ([[np.int32(747), np.int32(528)],
#    [np.int32(1405), np.int32(528)],
#    [np.int32(1405), np.int32(653)],
#    [np.int32(747), np.int32(653)]],
#   'kurabiye alsam',
#   np.float64(0.9991356308574215)),
#  ([[np.int32(1426), np.int32(525)],
#    [np.int32(2641), np.int32(525)],
#    [np.int32(2641), np.int32(647)],
#    [np.int32(1426), np.int32(647)]],
#   'olur mu? Tamam, yemekten',
#   np.float64(0.7071729432709369)),
#  ([[np.int32(2324), np.int32(642)],
#    [np.int32(2362), np.int32(642)],
#    [np.int32(2362), np.int32(680)],
# ...
